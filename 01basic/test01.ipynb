# %%
print("hello python")
# Out:
# hello python

# %%
# !python --version
# Out:
# Python 3.12.7

# %%
age = 20
print(age)
# Out:
# 20

# %%
print(f'테스트{age}')
# Out:
# 테스트20

# %%
print(f'당신의 나이는 {age}살 입니다.')
# Out:
# 당신의 나이는 20살 입니다.
