# %% [markdown]
# ### matplotlib 그래프그리기
#
# - year = [2014,2015,2016,2017,2018,2019,2020,2021,2022]
# - gdp = [3079.9,3250.1,3398.8,3574,3678.2,3721.8,3744,4003.6,4165.5]

# %%
import matplotlib.pyplot as plt

# %%
year = [2014,2015,2016,2017,2018,2019,2020,2021,2022]
gdp = [3079.9,3250.1,3398.8,3574,3678.2,3721.8,3744,4003.6,4165.5]
plt.plot(year,gdp)
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.plot(year,gdp,"--d")
plt.title('GDP per')
plt.xlabel('years')
plt.ylabel('won')
plt.show()

# %% [markdown]
# - year = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]
# - seoul = [12.1,12,12.2,12.5,13.4,13.6,13.6,13,12.9,13.5,13.2,13.7,13.2]
# - jeju = [15.6,15.6,15.7,16.5,16.2,16.7,17,16.8,16.6,16.8,16.7,17.5,17]

# %%
import matplotlib.pyplot as plt

year = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]
seoul = [12.1,12,12.2,12.5,13.4,13.6,13.6,13,12.9,13.5,13.2,13.7,13.2]
jeju = [15.6,15.6,15.7,16.5,16.2,16.7,17,16.8,16.6,16.8,16.7,17.5,17]

plt.figure(figsize=(5,4))
plt.plot(year,seoul,label="seoul")
plt.plot(year,jeju,label='jeju')
plt.title('years temp mean')
plt.legend()
plt.xlabel('years')
plt.ylabel('temp')
plt.show()

# %%
import numpy as np
year = np.array(year)

width = 0.2

plt.figure(figsize=(5,4))
plt.bar(year-width/2,jeju,width=width,label='jeju')
plt.bar(year+width/2,seoul,width=width,label="seoul")
plt.title('years temp mean')
plt.legend()
plt.xlabel('years')
plt.ylabel('temp')
plt.show()

# %%
import csv

tcount=0
count=0
date=[]


with open('data/seouldata2.csv',encoding='cp949') as tfile:
    data=csv.reader(tfile)
    next(data)
    for row in data:
        tcount += 1
        if row[-1] == '':
            count += 1
            date.append(row[0])

print(f'데이터 : 전체데이터 총 {tcount}개 / 최고온도 데이터 수 {count} / {tcount - count}')

date
# Out:
# 데이터 : 전체데이터 총 42431개 / 최고온도 데이터 수 760 / 41671
# ['\t1950-09-01',
#  '\t1950-09-02',
#  '\t1950-09-03',
#  '\t1950-09-04',
#  '\t1950-09-05',
#  '\t1950-09-06',
#  '\t1950-09-07',
#  '\t1950-09-08',
#  '\t1950-09-09',
#  '\t1950-09-10',
#  '\t1950-09-11',
#  '\t1950-09-12',
#  '\t1950-09-13',
#  '\t1950-09-14',
#  '\t1950-09-15',
#  '\t1950-09-16',
#  '\t1950-09-17',
#  '\t1950-09-18',
#  '\t1950-09-19',
#  '\t1950-09-20',
#  '\t1950-09-21',
#  '\t1950-09-22',
#  '\t1950-09-23',
#  '\t1950-09-24',
#  '\t1950-09-25',
#  '\t1950-10-01',
#  '\t1950-10-02',
#  '\t1950-10-03',
#  '\t1950-10-04',
#  '\t1950-10-05',
#  '\t1950-10-06',
#  '\t1950-10-07',
#  '\t1950-10-08',
#  '\t1950-10-09',
#  '\t1950-10-10',
#  '\t1950-10-11',
#  '\t1950-10-12',
#  '\t1950-10-13',
#  '\t1950-10-14',
#  '\t1950-10-15',
#  '\t1950-10-16',
#  '\t1950-10-17',
#  '\t1950-10-18',
#  '\t1950-10-19',
#  '\t1950-10-20',
#  '\t1950-10-21',
#  '\t1950-10-22',
#  '\t1950-10-23',
#  '\t1950-10-24',
#  '\t1950-10-25',
#  '\t1950-10-26',
#  '\t1950-10-27',
#  '\t1950-10-28',
#  '\t1950-10-29',
#  '\t1950-10-30',
#  '\t1950-10-31',
#  '\t1951-12-01',
#  '\t1951-12-02',
#  '\t1951-12-03',
#  '\t1951-12-04',
#  '\t1951-12-05',
#  '\t1951-12-06',
#  '\t1951-12-07',
#  '\t1951-12-08',
#  '\t1951-12-09',
#  '\t1951-12-10',
#  '\t1951-12-11',
#  '\t1951-12-12',
#  '\t1951-12-13',
#  '\t1951-12-14',
#  '\t1951-12-15',
#  '\t1951-12-16',
#  '\t1951-12-17',
#  '\t1951-12-18',
#  '\t1951-12-19',
#  '\t1951-12-20',
#  '\t1951-12-21',
#  '\t1951-12-22',
#  '\t1951-12-23',
#  '\t1951-12-24',
#  '\t1951-12-25',
#  '\t1951-12-26',
#  '\t1951-12-27',
#  '\t1951-12-28',
#  '\t1951-12-29',
#  '\t1951-12-30',
#  '\t1951-12-31',
#  '\t1952-01-01',
#  '\t1952-01-02',
#  '\t1952-01-03',
#  '\t1952-01-04',
#  '\t1952-01-05',
#  '\t1952-01-06',
#  '\t1952-01-07',
#  '\t1952-01-08',
#  '\t1952-01-09',
#  '\t1952-01-10',
#  '\t1952-01-11',
#  '\t1952-01-12',
#  '\t1952-01-13',
#  '\t1952-01-14',
#  '\t1952-01-15',
#  '\t1952-01-16',
#  '\t1952-01-17',
#  '\t1952-01-18',
#  '\t1952-01-19',
#  '\t1952-01-20',
#  '\t1952-01-21',
#  '\t1952-01-22',
#  '\t1952-01-23',
#  '\t1952-01-24',
#  '\t1952-01-25',
#  '\t1952-01-26',
#  '\t1952-01-27',
#  '\t1952-01-28',
#  '\t1952-01-29',
#  '\t1952-01-30',
#  '\t1952-01-31',
#  '\t1952-02-01',
#  '\t1952-02-02',
#  '\t1952-02-03',
#  '\t1952-02-04',
#  '\t1952-02-05',
#  '\t1952-02-06',
#  '\t1952-02-07',
#  '\t1952-02-08',
#  '\t1952-02-09',
#  '\t1952-02-10',
#  '\t1952-02-11',
#  '\t1952-02-12',
#  '\t1952-02-13',
#  '\t1952-02-14',
#  '\t1952-02-15',
#  '\t1952-02-16',
#  '\t1952-02-17',
#  '\t1952-02-18',
#  '\t1952-02-19',
#  '\t1952-02-20',
#  '\t1952-02-21',
#  '\t1952-02-22',
#  '\t1952-02-23',
#  '\t1952-02-24',
#  '\t1952-02-25',
#  '\t1952-02-26',
#  '\t1952-02-27',
#  '\t1952-02-28',
#  '\t1952-02-29',
#  '\t1952-03-01',
#  '\t1952-03-02',
#  '\t1952-03-03',
#  '\t1952-03-04',
#  '\t1952-03-05',
#  '\t1952-03-06',
#  '\t1952-03-07',
#  '\t1952-03-08',
#  '\t1952-03-09',
#  '\t1952-03-10',
#  '\t1952-03-11',
#  '\t1952-03-12',
#  '\t1952-03-13',
#  '\t1952-03-14',
#  '\t1952-03-15',
#  '\t1952-03-16',
#  '\t1952-03-17',
#  '\t1952-03-18',
#  '\t1952-03-19',
#  '\t1952-03-20',
#  '\t1952-03-21',
#  '\t1952-03-22',
#  '\t1952-03-23',
#  '\t1952-03-24',
#  '\t1952-03-25',
#  '\t1952-03-26',
#  '\t1952-03-27',
#  '\t1952-03-28',
#  '\t1952-03-29',
#  '\t1952-03-30',
#  '\t1952-03-31',
#  '\t1952-04-01',
#  '\t1952-04-02',
#  '\t1952-04-03',
#  '\t1952-04-04',
#  '\t1952-04-05',
#  '\t1952-04-06',
#  '\t1952-04-07',
#  '\t1952-04-08',
#  '\t1952-04-09',
#  '\t1952-04-10',
#  '\t1952-04-11',
#  '\t1952-04-12',
#  '\t1952-04-13',
#  '\t1952-04-14',
#  '\t1952-04-15',
#  '\t1952-04-16',
#  '\t1952-04-17',
#  '\t1952-04-18',
#  '\t1952-04-19',
#  '\t1952-04-20',
#  '\t1952-04-21',
#  '\t1952-04-22',
#  '\t1952-04-23',
#  '\t1952-04-24',
#  '\t1952-04-25',
#  '\t1952-04-26',
#  '\t1952-04-27',
#  '\t1952-04-28',
#  '\t1952-04-29',
#  '\t1952-04-30',
#  '\t1952-05-01',
#  '\t1952-05-02',
#  '\t1952-05-03',
#  '\t1952-05-04',
#  '\t1952-05-05',
#  '\t1952-05-06',
#  '\t1952-05-07',
#  '\t1952-05-08',
#  '\t1952-05-09',
#  '\t1952-05-10',
#  '\t1952-05-11',
#  '\t1952-05-12',
#  '\t1952-05-13',
#  '\t1952-05-14',
#  '\t1952-05-15',
#  '\t1952-05-16',
#  '\t1952-05-17',
#  '\t1952-05-18',
#  '\t1952-05-19',
#  '\t1952-05-20',
#  '\t1952-05-21',
#  '\t1952-05-22',
#  '\t1952-05-23',
#  '\t1952-05-24',
#  '\t1952-05-25',
#  '\t1952-05-26',
#  '\t1952-05-27',
#  '\t1952-05-28',
#  '\t1952-05-29',
#  '\t1952-05-30',
#  '\t1952-05-31',
#  '\t1952-06-01',
#  '\t1952-06-02',
#  '\t1952-06-03',
#  '\t1952-06-04',
#  '\t1952-06-05',
#  '\t1952-06-06',
#  '\t1952-06-07',
#  '\t1952-06-08',
#  '\t1952-06-09',
#  '\t1952-06-10',
#  '\t1952-06-11',
#  '\t1952-06-12',
#  '\t1952-06-13',
#  '\t1952-06-14',
#  '\t1952-06-15',
#  '\t1952-06-16',
#  '\t1952-06-17',
#  '\t1952-06-18',
#  '\t1952-06-19',
#  '\t1952-06-20',
#  '\t1952-06-21',
#  '\t1952-06-22',
#  '\t1952-06-23',
#  '\t1952-06-24',
#  '\t1952-06-25',
#  '\t1952-06-26',
#  '\t1952-06-27',
#  '\t1952-06-28',
#  '\t1952-06-29',
#  '\t1952-06-30',
#  '\t1952-07-01',
#  '\t1952-07-02',
#  '\t1952-07-03',
#  '\t1952-07-04',
#  '\t1952-07-05',
#  '\t1952-07-06',
#  '\t1952-07-07',
#  '\t1952-07-08',
#  '\t1952-07-09',
#  '\t1952-07-10',
#  '\t1952-07-11',
#  '\t1952-07-12',
#  '\t1952-07-13',
#  '\t1952-07-14',
#  '\t1952-07-15',
#  '\t1952-07-16',
#  '\t1952-07-17',
#  '\t1952-07-18',
#  '\t1952-07-19',
#  '\t1952-07-20',
#  '\t1952-07-21',
#  '\t1952-07-22',
#  '\t1952-07-23',
#  '\t1952-07-24',
#  '\t1952-07-25',
#  '\t1952-07-26',
#  '\t1952-07-27',
#  '\t1952-07-28',
#  '\t1952-07-29',
#  '\t1952-07-30',
#  '\t1952-07-31',
#  '\t1952-09-01',
#  '\t1952-09-02',
#  '\t1952-09-03',
#  '\t1952-09-04',
#  '\t1952-09-05',
#  '\t1952-09-06',
#  '\t1952-09-07',
#  '\t1952-09-08',
#  '\t1952-09-09',
#  '\t1952-09-10',
#  '\t1952-09-11',
#  '\t1952-09-12',
#  '\t1952-09-13',
#  '\t1952-09-14',
#  '\t1952-09-15',
#  '\t1952-09-16',
#  '\t1952-09-17',
#  '\t1952-09-18',
#  '\t1952-09-19',
#  '\t1952-09-20',
#  '\t1952-09-21',
#  '\t1952-09-22',
#  '\t1952-09-23',
#  '\t1952-09-24',
#  '\t1952-09-25',
#  '\t1952-09-26',
#  '\t1952-09-27',
#  '\t1952-09-28',
#  '\t1952-09-29',
#  '\t1952-09-30',
#  '\t1952-10-01',
#  '\t1952-10-02',
#  '\t1952-10-03',
#  '\t1952-10-04',
#  '\t1952-10-05',
#  '\t1952-10-06',
#  '\t1952-10-07',
#  '\t1952-10-08',
#  '\t1952-10-09',
#  '\t1952-10-10',
#  '\t1952-10-11',
#  '\t1952-10-12',
#  '\t1952-10-13',
#  '\t1952-10-14',
#  '\t1952-10-15',
#  '\t1952-10-16',
#  '\t1952-10-17',
#  '\t1952-10-18',
#  '\t1952-10-19',
#  '\t1952-10-20',
#  '\t1952-10-21',
#  '\t1952-10-22',
#  '\t1952-10-23',
#  '\t1952-10-24',
#  '\t1952-10-25',
#  '\t1952-10-26',
#  '\t1952-10-27',
#  '\t1952-10-28',
#  '\t1952-10-29',
#  '\t1952-10-30',
#  '\t1952-10-31',
#  '\t1952-11-01',
#  '\t1952-11-02',
#  '\t1952-11-03',
#  '\t1952-11-04',
#  '\t1952-11-05',
#  '\t1952-11-06',
#  '\t1952-11-07',
#  '\t1952-11-08',
#  '\t1952-11-09',
#  '\t1952-11-10',
#  '\t1952-11-11',
#  '\t1952-11-12',
#  '\t1952-11-13',
#  '\t1952-11-14',
#  '\t1952-11-15',
#  '\t1952-11-16',
#  '\t1952-11-17',
#  '\t1952-11-18',
#  '\t1952-11-19',
#  '\t1952-11-20',
#  '\t1952-11-21',
#  '\t1952-11-22',
#  '\t1952-11-23',
#  '\t1952-11-24',
#  '\t1952-11-25',
#  '\t1952-11-26',
#  '\t1952-11-27',
#  '\t1952-11-28',
#  '\t1952-11-29',
#  '\t1952-11-30',
#  '\t1952-12-01',
#  '\t1952-12-02',
#  '\t1952-12-03',
#  '\t1952-12-04',
#  '\t1952-12-05',
#  '\t1952-12-06',
#  '\t1952-12-07',
#  '\t1952-12-08',
#  '\t1952-12-09',
#  '\t1952-12-10',
#  '\t1952-12-11',
#  '\t1952-12-12',
#  '\t1952-12-13',
#  '\t1952-12-14',
#  '\t1952-12-15',
#  '\t1952-12-16',
#  '\t1952-12-17',
#  '\t1952-12-18',
#  '\t1952-12-19',
#  '\t1952-12-20',
#  '\t1952-12-21',
#  '\t1952-12-22',
#  '\t1952-12-23',
#  '\t1952-12-24',
#  '\t1952-12-25',
#  '\t1952-12-26',
#  '\t1952-12-27',
#  '\t1952-12-28',
#  '\t1952-12-29',
#  '\t1952-12-30',
#  '\t1952-12-31',
#  '\t1953-01-01',
#  '\t1953-01-02',
#  '\t1953-01-03',
#  '\t1953-01-04',
#  '\t1953-01-05',
#  '\t1953-01-06',
#  '\t1953-01-07',
#  '\t1953-01-08',
#  '\t1953-01-09',
#  '\t1953-01-10',
#  '\t1953-01-11',
#  '\t1953-01-12',
#  '\t1953-01-13',
#  '\t1953-01-14',
#  '\t1953-01-15',
#  '\t1953-01-16',
#  '\t1953-01-17',
#  '\t1953-01-18',
#  '\t1953-01-19',
#  '\t1953-01-20',
#  '\t1953-01-21',
#  '\t1953-01-22',
#  '\t1953-01-23',
#  '\t1953-01-24',
#  '\t1953-01-25',
#  '\t1953-01-26',
#  '\t1953-01-27',
#  '\t1953-01-28',
#  '\t1953-01-29',
#  '\t1953-01-30',
#  '\t1953-01-31',
#  '\t1953-02-01',
#  '\t1953-02-02',
#  '\t1953-02-03',
#  '\t1953-02-04',
#  '\t1953-02-05',
#  '\t1953-02-06',
#  '\t1953-02-07',
#  '\t1953-02-08',
#  '\t1953-02-09',
#  '\t1953-02-10',
#  '\t1953-02-11',
#  '\t1953-02-12',
#  '\t1953-02-13',
#  '\t1953-02-14',
#  '\t1953-02-15',
#  '\t1953-02-16',
#  '\t1953-02-17',
#  '\t1953-02-18',
#  '\t1953-02-19',
#  '\t1953-02-20',
#  '\t1953-02-21',
#  '\t1953-02-22',
#  '\t1953-02-23',
#  '\t1953-02-24',
#  '\t1953-02-25',
#  '\t1953-02-26',
#  '\t1953-02-27',
#  '\t1953-02-28',
#  '\t1953-03-01',
#  '\t1953-03-02',
#  '\t1953-03-03',
#  '\t1953-03-04',
#  '\t1953-03-05',
#  '\t1953-03-06',
#  '\t1953-03-07',
#  '\t1953-03-08',
#  '\t1953-03-09',
#  '\t1953-03-10',
#  '\t1953-03-11',
#  '\t1953-03-12',
#  '\t1953-03-13',
#  '\t1953-03-14',
#  '\t1953-03-15',
#  '\t1953-03-16',
#  '\t1953-03-17',
#  '\t1953-03-18',
#  '\t1953-03-19',
#  '\t1953-03-20',
#  '\t1953-03-21',
#  '\t1953-03-22',
#  '\t1953-03-23',
#  '\t1953-03-24',
#  '\t1953-03-25',
#  '\t1953-03-26',
#  '\t1953-03-27',
#  '\t1953-03-28',
#  '\t1953-03-29',
#  '\t1953-03-30',
#  '\t1953-03-31',
#  '\t1953-04-01',
#  '\t1953-04-02',
#  '\t1953-04-03',
#  '\t1953-04-04',
#  '\t1953-04-05',
#  '\t1953-04-06',
#  '\t1953-04-07',
#  '\t1953-04-08',
#  '\t1953-04-09',
#  '\t1953-04-10',
#  '\t1953-04-11',
#  '\t1953-04-12',
#  '\t1953-04-13',
#  '\t1953-04-14',
#  '\t1953-04-15',
#  '\t1953-04-16',
#  '\t1953-04-17',
#  '\t1953-04-18',
#  '\t1953-04-19',
#  '\t1953-04-20',
#  '\t1953-04-21',
#  '\t1953-04-22',
#  '\t1953-04-23',
#  '\t1953-04-24',
#  '\t1953-04-25',
#  '\t1953-04-26',
#  '\t1953-04-27',
#  '\t1953-04-28',
#  '\t1953-04-29',
#  '\t1953-04-30',
#  '\t1953-05-01',
#  '\t1953-05-02',
#  '\t1953-05-03',
#  '\t1953-05-04',
#  '\t1953-05-05',
#  '\t1953-05-06',
#  '\t1953-05-07',
#  '\t1953-05-08',
#  '\t1953-05-09',
#  '\t1953-05-10',
#  '\t1953-05-11',
#  '\t1953-05-12',
#  '\t1953-05-13',
#  '\t1953-05-14',
#  '\t1953-05-15',
#  '\t1953-05-16',
#  '\t1953-05-17',
#  '\t1953-05-18',
#  '\t1953-05-19',
#  '\t1953-05-20',
#  '\t1953-05-21',
#  '\t1953-05-22',
#  '\t1953-05-23',
#  '\t1953-05-24',
#  '\t1953-05-25',
#  '\t1953-05-26',
#  '\t1953-05-27',
#  '\t1953-05-28',
#  '\t1953-05-29',
#  '\t1953-05-30',
#  '\t1953-05-31',
#  '\t1953-06-01',
#  '\t1953-06-02',
#  '\t1953-06-03',
#  '\t1953-06-04',
#  '\t1953-06-05',
#  '\t1953-06-06',
#  '\t1953-06-07',
#  '\t1953-06-08',
#  '\t1953-06-09',
#  '\t1953-06-10',
#  '\t1953-06-11',
#  '\t1953-06-12',
#  '\t1953-06-13',
#  '\t1953-06-14',
#  '\t1953-06-15',
#  '\t1953-06-16',
#  '\t1953-06-17',
#  '\t1953-06-18',
#  '\t1953-06-19',
#  '\t1953-06-20',
#  '\t1953-06-21',
#  '\t1953-06-22',
#  '\t1953-06-23',
#  '\t1953-06-24',
#  '\t1953-06-25',
#  '\t1953-06-26',
#  '\t1953-06-27',
#  '\t1953-06-28',
#  '\t1953-06-29',
#  '\t1953-06-30',
#  '\t1953-07-01',
#  '\t1953-07-02',
#  '\t1953-07-03',
#  '\t1953-07-04',
#  '\t1953-07-05',
#  '\t1953-07-06',
#  '\t1953-07-07',
#  '\t1953-07-08',
#  '\t1953-07-09',
#  '\t1953-07-10',
#  '\t1953-07-11',
#  '\t1953-07-12',
#  '\t1953-07-13',
#  '\t1953-07-14',
#  '\t1953-07-15',
#  '\t1953-07-16',
#  '\t1953-07-17',
#  '\t1953-07-18',
#  '\t1953-07-19',
#  '\t1953-07-20',
#  '\t1953-07-21',
#  '\t1953-07-22',
#  '\t1953-07-23',
#  '\t1953-07-24',
#  '\t1953-07-25',
#  '\t1953-07-26',
#  '\t1953-07-27',
#  '\t1953-07-28',
#  '\t1953-07-29',
#  '\t1953-07-30',
#  '\t1953-07-31',
#  '\t1953-08-01',
#  '\t1953-08-02',
#  '\t1953-08-03',
#  '\t1953-08-04',
#  '\t1953-08-05',
#  '\t1953-08-06',
#  '\t1953-08-07',
#  '\t1953-08-08',
#  '\t1953-08-09',
#  '\t1953-08-10',
#  '\t1953-08-11',
#  '\t1953-08-12',
#  '\t1953-08-13',
#  '\t1953-08-14',
#  '\t1953-08-15',
#  '\t1953-08-16',
#  '\t1953-08-17',
#  '\t1953-08-18',
#  '\t1953-08-19',
#  '\t1953-08-20',
#  '\t1953-08-21',
#  '\t1953-08-22',
#  '\t1953-08-23',
#  '\t1953-08-24',
#  '\t1953-08-25',
#  '\t1953-08-26',
#  '\t1953-08-27',
#  '\t1953-08-28',
#  '\t1953-08-29',
#  '\t1953-08-30',
#  '\t1953-08-31',
#  '\t1953-09-01',
#  '\t1953-09-02',
#  '\t1953-09-03',
#  '\t1953-09-04',
#  '\t1953-09-05',
#  '\t1953-09-06',
#  '\t1953-09-07',
#  '\t1953-09-08',
#  '\t1953-09-09',
#  '\t1953-09-10',
#  '\t1953-09-11',
#  '\t1953-09-12',
#  '\t1953-09-13',
#  '\t1953-09-14',
#  '\t1953-09-15',
#  '\t1953-09-16',
#  '\t1953-09-17',
#  '\t1953-09-18',
#  '\t1953-09-19',
#  '\t1953-09-20',
#  '\t1953-09-21',
#  '\t1953-09-22',
#  '\t1953-09-23',
#  '\t1953-09-24',
#  '\t1953-09-25',
#  '\t1953-09-26',
#  '\t1953-09-27',
#  '\t1953-09-28',
#  '\t1953-09-29',
#  '\t1953-09-30',
#  '\t1953-10-01',
#  '\t1953-10-02',
#  '\t1953-10-03',
#  '\t1953-10-04',
#  '\t1953-10-05',
#  '\t1953-10-06',
#  '\t1953-10-07',
#  '\t1953-10-08',
#  '\t1953-10-09',
#  '\t1953-10-10',
#  '\t1953-10-11',
#  '\t1953-10-12',
#  '\t1953-10-13',
#  '\t1953-10-14',
#  '\t1953-10-15',
#  '\t1953-10-16',
#  '\t1953-10-17',
#  '\t1953-10-18',
#  '\t1953-10-19',
#  '\t1953-10-20',
#  '\t1953-10-21',
#  '\t1953-10-22',
#  '\t1953-10-23',
#  '\t1953-10-24',
#  '\t1953-10-25',
#  '\t1953-10-26',
#  '\t1953-10-27',
#  '\t1953-10-28',
#  '\t1953-10-29',
#  '\t1953-10-30',
#  '\t1953-10-31',
#  '\t1953-11-01',
#  '\t1953-11-02',
#  '\t1953-11-03',
#  '\t1953-11-04',
#  '\t1953-11-05',
#  '\t1953-11-06',
#  '\t1953-11-07',
#  '\t1953-11-08',
#  '\t1953-11-09',
#  '\t1953-11-10',
#  '\t1953-11-11',
#  '\t1953-11-12',
#  '\t1953-11-13',
#  '\t1953-11-14',
#  '\t1953-11-15',
#  '\t1953-11-16',
#  '\t1953-11-17',
#  '\t1953-11-18',
#  '\t1953-11-19',
#  '\t1953-11-20',
#  '\t1953-11-21',
#  '\t1953-11-22',
#  '\t1953-11-23',
#  '\t1953-11-24',
#  '\t1953-11-25',
#  '\t1953-11-26',
#  '\t1953-11-27',
#  '\t1953-11-28',
#  '\t1953-11-29',
#  '\t1953-11-30',
#  '\t1967-02-19',
#  '\t1973-10-16',
#  '\t2017-10-12',
#  '\t']

# %%
plt.hist(htemp,bins=100)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y = [1,4,9,16]
y1 = [16,9,4,1]

plt.figure(figsize=(4,3))
plt.plot(x,y,color='g',linestyle=":",marker='d')
plt.plot(x,y1,color='r',linestyle=":",marker='d')
plt.title('bar')
# plt.bar(x,y)
plt.xlabel('location')
plt.ylabel('height')
plt.xlim(0,10)
plt.ylim(0,30)
plt.show()

# %%
# Out:
# 동물별 평균 수치: [ 51.16666667  44.7        198.93333333]
# 가장 무거운 동물: 말 500.0kg
