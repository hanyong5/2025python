# %%
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

# %%
img = cv2.imread('img/digits.png',cv2.IMREAD_GRAYSCALE)
# img.shape

cells = [np.hsplit(row,100) for row in np.vsplit(img,50)]
x = np.array(cells)
x.shape
# Out:
# (50, 100, 20, 20)

# %%
# cnn -> (5000, 20, 20, 1)
X = x.reshape(-1,20,20,1).astype(np.float32) / 255.0
y = np.repeat(np.arange(10),500)
X.shape
# Out:
# (5000, 20, 20, 1)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
model = keras.Sequential([
    keras.Input(shape=(20,20,1)),
    keras.layers.Conv2D(32, kernel_size=3,padding='same',activation='relu'),
    keras.layers.MaxPooling2D(2),
    keras.layers.Conv2D(63, kernel_size=3,padding='same',activation='relu'),
    keras.layers.MaxPooling2D(2),
    keras.layers.Flatten(),
    keras.layers.Dense(128,activation='relu'),
    keras.layers.Dropout(0.4),
    keras.layers.Dense(10,activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['acc']
)
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 20, 20, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 10, 10, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 10, 10, 63)     │        18,207 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 63)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1575)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       201,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 221,545 (865.41 KB)
#  Trainable params: 221,545 (865.41 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stop = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)
model.fit(X_train,y_train, epochs=20, validation_split=0.2,callbacks=early_stop)
# Out:
# Epoch 1/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - acc: 0.6236 - loss: 1.1690 - val_acc: 0.8886 - val_loss: 0.3783
# Epoch 2/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.8829 - loss: 0.3832 - val_acc: 0.9571 - val_loss: 0.1792
# Epoch 3/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - acc: 0.9307 - loss: 0.2455 - val_acc: 0.9571 - val_loss: 0.1429
# Epoch 4/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - acc: 0.9393 - loss: 0.1883 - val_acc: 0.9743 - val_loss: 0.1036
# Epoch 5/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - acc: 0.9521 - loss: 0.1543 - val_acc: 0.9686 - val_loss: 0.1037
# Epoch 6/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - acc: 0.9607 - loss: 0.1333 - val_acc: 0.9743 - val_loss: 0.0881
# Epoch 7/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - acc: 0.9654 - loss: 0.1015 - val_acc: 0.9729 - val_loss: 0.0768
# Epoch 8/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - acc: 0.9750 - loss: 0.0811 - val_acc: 0.9786 - val_loss: 0.0871
# Epoch 9/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - acc: 0.9682 - loss: 0.0866 - val_acc: 0.9786 - val_loss: 0.0685
# Epoch 10/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - acc: 0.9821 - loss: 0.0677 - val_acc: 0.9757 - val_loss: 0.0753
# Epoch 11/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - acc: 0.9843 - loss: 0.0498 - val_acc: 0.9700 - val_loss: 0.0966
# Epoch 12/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - acc: 0.9789 - loss: 0.0637 - val_acc: 0.9800 - val_loss: 0.0726

# %%
loss,acc=model.evaluate(X_test,y_test)
print(f'테스트 정확도:{acc:.4f}')
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acc: 0.9767 - loss: 0.0968
# 테스트 정확도:0.9767

# %%
import cv2
import numpy as np

# 1. 이미지 읽기
img = cv2.imread("img/numbers.jpg")

# 2. 컬러 → 흑백
g_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# blur 적용
g_img = cv2.medianBlur(g_img,5)



# 3. 이진화 (적응형)
bin_img = cv2.adaptiveThreshold(
    g_img, 255,
    cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
    cv2.THRESH_BINARY_INV,
    11, 2
)



# 3. 이진화 (적응형)
# thr, bin_img = cv2.threshold(g_img, 110, 255, cv2.THRESH_BINARY_INV)


# 몰핀
kernel = np.ones((2,2), np.uint8)
bin_img = cv2.morphologyEx(bin_img, cv2.MORPH_OPEN, kernel)




# 4. 컨투어 찾기
contours, hierarchy = cv2.findContours(
    bin_img,
    cv2.RETR_EXTERNAL,
    cv2.CHAIN_APPROX_SIMPLE
)

h, w = bin_img.shape[:2]

for contour in contours:

    (x, y), radius = cv2.minEnclosingCircle(contour)

    if radius > 3:
        xs = max(0, int(x-radius))
        xe = min(w, int(x+radius))
        ys = max(0, int(y-radius))
        ye = min(h, int(y+radius))

        cv2.rectangle(bin_img, (xs, ys), (xe, ye), (255,255,255), 1)

        roi = bin_img[ys:ye, xs:xe]
        if roi.size == 0:
            continue

        dst = cv2.resize(roi, (50, 50))
        dst = cv2.resize(dst, (16, 16))

        A = np.zeros((20, 20))
        A[2:-2, 2:-2] = dst

        # CNN 입력: (1, 20, 20, 1), 정규화
        A = A.reshape(1, 20, 20, 1).astype(np.float32) / 255.0

        pred = model.predict(A, verbose=0)
        num = np.argmax(pred)

        cv2.putText(
            bin_img,
            str(num),
            (xs, ys),
            cv2.FONT_HERSHEY_PLAIN,
            2,
            (200, 0, 0)
        )

cv2.imshow("Image", bin_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
