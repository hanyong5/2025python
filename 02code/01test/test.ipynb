# %% [markdown]
# ### 제목
# **test**
# test1
#
# - 데이터수집
# - 데치터 전처리
#     - 결측치 처리
#     - 이상치
#
# 1. 데이터불러오기
# 1. 모델학습
# 1. 결과평가
#
# `print("hello python")`
#
# ```python
# print("hello python")
# df=pd.read_csv("test.csv")
# ```
# ---
#
# |컬럼|설명|
# |----|----|
# |x|입력|
#
# 구글링크 : [구글](http://www.google.com)
# ![이미지](이미지경로)
#
# ---
#
# - [x] 데이터로드
# - [] 테스트
# - [ ] 결과 시각화

# %%
print("test")
# Out:
# test

# %%
age = 100
print(age)
# Out:
# 100

# %%
print(f'당신의 나이는 {age}')
# Out:
# 당신의 나이는 100

# %%
type(age)
type("test")
# Out:
# str

# %%
print(type(age))
print(type("test"))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a = int(input("정수:"))
b = int(input("정수:"))
print(a+b)
# Out:
# 20

# %%
print(type(0.3))
print(type(True))
# Out:
# <class 'float'>
# <class 'bool'>

# %%
c = float(input("시간입력 : "))
d = c * 60
print(f'{d}초 입니다.')
# Out:
# 120.0초 입니다.

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y = [10,20,25,30]

# plt.plot(x,y)
plt.bar(x,y)
plt.show()

# %%
s = [1,2,3,4,5]
scroe = [60,65,70,85,100]
plt.bar(s,scroe)
plt.xlabel("study time")
plt.ylabel('Score')
plt.title("study time vs score")
plt.show()

# %%
import random
r = random.randint(1,10)
print(r)
answer = int(input("숫자를 맞워보세요 : "))
print(f'{r == answer} 선택한 수는 {answer} 이고 답은 {r} 입니다.')
# Out:
# 3
# False 선택한 수는 5 이고 답은 3 입니다.

# %%
import random
text = ['서울','부산','대구','대전','제주'] # list
# print(text[0])
# c = random.randint(0,4)
c = random.randint(0,len(text)-1)
print(text[c])
# Out:
# 대전

# %% [markdown]
# ### range(start,stop,step)

# %%
print(range(5))


# for i in range(1,10,3):
#     print(i)


for i in range(0,10):
    print(i)
    print("hi")
# Out:
# range(0, 5)
# 0
# hi
# 1
# hi
# 2
# hi
# 3
# hi
# 4
# hi
# 5
# hi
# 6
# hi
# 7
# hi
# 8
# hi
# 9
# hi

# %%
for i in range(5):
    print(text[i])
# Out:
# 서울
# 부산
# 대구
# 대전
# 제주

# %%
# const number=[]
# for(var i=1;i<100;i++){
#     number.push(i)
# }
# document.write(number)
import random

numbers = list(range(1,46))
# print(numbers)

lotto = random.sample(numbers,6)
lotto.sort()
print(lotto)
# Out:
# [2, 6, 9, 19, 20, 22]

# %%
import random

for i in 1,6,4:
    print(i)

for i in range(0,3):
    print(i)

for i in range(0,5):
    print("홍길동")
# Out:
# 1
# 6
# 4
# 0
# 1
# 2
# 홍길동
# 홍길동
# 홍길동
# 홍길동
# 홍길동

# %%
sum=0
for i in range(1,101):
    # sum = sum + i
    sum += i
    # print(sum)
print(f'합계는 {sum} 입니다.')
# Out:
# 합계는 5050 입니다.

# %%
for i in range(5):
    print(text[i])
# Out:
# 서울
# 부산
# 대구
# 대전
# 제주

# %%
import random
a = random.randint(1,100)
b = random.randint(1,100)
#a 10 b 20

if a<b:
    a,b=a,b
else:
    a,b=b,a


print(a,b)
# Out:
# 49 72

# %% [markdown]
# ### 두학생의 키 차이를 구하기

# %%
h1 = int(input("키:"))
h2 = int(input("키:"))

if h1 > h2:
    print(f'키차이: {h1-h2}')
else:
    print(f'키차이: {h2-h1}')
# Out:
# 키차이: 50

# %% [markdown]
# ### if~elif~else 문
# - 놀이공원 기본 입장료가 5,000원이고 나이에 따른 할인율이 다음과 같은 경우, 나이를 입력받아 입장료를 구하는 프로그램을 만들어보기
#
# ![이미지](img/img01_01.png)
